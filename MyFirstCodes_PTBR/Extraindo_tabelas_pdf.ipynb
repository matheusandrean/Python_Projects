# %%
import tabula as tb
import pandas as pd
import dataframe_image as dfi
import numpy as np

# %%
#Comando para exibir as tabelas de um determinado arquivo.
tabela_principal = tb.read_pdf("SUL_Oseltamivir.pdf", pages ="all", encoding = 'utf-8')
#Comando para mostrar quantas tabelas existem em um determinado arquivo. 
print(len(tabela_principal))
# Out:
# 4

# %%
#Comando para exibir as tabelas existentes no arquivo. 
for tabela in tabela_principal:
    display(tabela)
# Out:
#       POLOS DE DISPENSAÇÃO DE OSELTAMIVIR - CRS SUL  \
# 0                                   NOME DA UNIDADE
# 1                         SAE DST/AIDS CIDADE DUTRA
# 2                          UBS ALCINA PIMENTEL PIZA
# 3                                  UBS JORDANÓPOLIS
# 4                                      UBS VELEIROS
# 5                                 AMA CAPÃO REDONDO
# 6             AMA ESPECIALIDADES JARDIM PIRAJUSSARA
# 7                 AMA/UBS INTEGRADA PARQUE FERNANDA
# 8                                 AMA/UBS VILA PREL
# 9                     SAE DST/AIDS JARDIM MITSUTANI
# 10                                 UBS JARDIM ELEDY
# 11                             UBS ALTO DO UMUARAMA
# 12                                  UBS CAMPO LIMPO
# 13           UBS DR FRANCISCO S SOBRINHO - ARRASTÃO
# 14  UBS DR VITTÓRIO ROLANDO BOCALETTI ( VILA PRAIA)
# 15                             UBS JARDIM COMERCIAL
# 16                            UBS JARDIM DAS PALMAS
# ...

# %%
#O método abaixo torna a linha definida como sendo o cabeçalho da nossa tabela.
tabela.columns = tabela.iloc[0]
#Comando para fazer com que a tabela seja medida a partir da linha de nº1
tabela = tabela[1:]
tabela
# Out:
# 2                                 UBS JARDIM SILVEIRA  \
# 3                                        UBS MARSILAC
# 4                                    UBS NOVA AMÉRICA
# 5                              UBS RECANTO CAMPO BELO
# 6                                   UBS VARGEM GRANDE
# 7                                       UBS VERA POTY
# 8                      UBS VILA MARCELO - PARELHEIROS
# 9                                    UBS VILA ROSCHEL
# 10  AMA / UBS INTEGRADA JD. MIRIAM - MANOEL SOARES...
# 11  AMA ESPECIALIDADES VILA CONSTÂNCIA - DR VICENT...
# 12             AMA PEDREIRA DR CESAR ANTUNES DA ROCHA
# 13                     AMA/UBS INTEGRADA VILA JOANIZA
# 14                 AMA/UBS INTEGRADA VILA MISSIONARIA
# 15          CENTRO DE REFERÊNCIA DST/AIDS SANTO AMARO
# 16          PSF VILA IMPÉRIO II DRA GILDA TERA TAHIRA
# 17                     UBS/AMA INTEGRADA VILA IMPÉRIO
# 18                                   UBS CAMPO GRANDE
# ...

# %%
import dataframe_image as dfi
import numpy as np

# %%
tabelaconjunta = pd.concat([tabela[1:], tabela[2:]])

# %%
tabelaconjunta
# Out:
# 2                            UBS JARDIM SILVEIRA  \
# 4                               UBS NOVA AMÉRICA
# 5                         UBS RECANTO CAMPO BELO
# 6                              UBS VARGEM GRANDE
# 7                                  UBS VERA POTY
# 8                 UBS VILA MARCELO - PARELHEIROS
# ..                                           ...
# 33                               UBS SANTO AMARO
# 34                                 UBS SÃO JORGE
# 35                            UBS VILA APARECIDA
# 36  UBS VILA ARRIETE - DR. DÉCIO PACHECO PEDROSO
# 37                      UBS/PSF JARDIM MIRIAM II
#
# 2         RUA BONIFÁCIO ASIOLI, N. 162  5921-5294  \
# 4      RUA EDUARDO COLIER FILHO, N. 12  5977-3507
# 5            RUA VIRGINIA MODESTO, 800  5926-2002
# 6                   RUA DA ARARAS, 498  5921-2111
# 7                   EST JOÃO LANG, 153  5977-3851
# 8   RUA AMADO BENEDITO VILAS BOAS, 616  5979-8972
# ..                                 ...        ...
# ...

# %%
import pdfkit as pdf
import sqlite3
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import dataframe_image as dfi

# %%
tabelaconjunta = pd.DataFrame(np.random.randn(6,6)dfi.export(tabelaconjunta, 'tabelaconjunta.png')
